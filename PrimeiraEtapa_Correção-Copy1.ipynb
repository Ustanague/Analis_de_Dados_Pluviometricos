# %% [markdown]
# # Primeira Etapa da Correção dos Dados:
#
# ### Aglutinação e algumas retiradas:

# %% [markdown]
# ### Importações

# %%
#Manipualão do Data Frame
import pandas as pd
from glob import glob #Para construção do banco de dados através da unificação das planilhas

# %%
#Manipulação dos arquivos
import shutil
from os import remove

# %% [markdown]
# ### Código

# %% [markdown]
# Puxando as tabelas

# %%
abv = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Alto da Boa Vista\*'))
anchi = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Anchieta\*'))
am = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\av mendanha\*'))
bangu = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Bangu\*'))
bar = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Barrinha\*'))
cg = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Campo Grande\*'))
cdd = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Cidade de Deus\*'))
copa = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Copacabana\*'))
grajau = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Grajau\*'))
grajaca = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Grajau-Jacarepagua\*'))
grota = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Grota Funda\*'))
guaratiba = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Guaratiba\*'))
ilha = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Ilha do Governador\*'))
iraja = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Iraja\*'))
jardimbo = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Jardim Botanico\*'))
laranjeiras = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Laranjeiras\*'))
meier = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Meier\*'))
madu = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Madureira\*'))
penha = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Penha\*'))
piedade = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Piedade\*'))
recreio = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Recreio\*'))
riocentro = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Rio Centro\*'))
rocinha = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Rocinha\*'))
santacruz = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Santa Cruz\*'))
santateresa = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Santa Teresa\*'))
saocristo = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\São Cristovao\*'))
saude = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Saude\*'))
sepetiba = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Sepetiba\*'))
tanque = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Tanque\*'))
tijuca = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Tijuca\*'))
tijucamuda = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Tijuca_muda\*'))
urca = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Urca\*'))
vidigal = sorted(glob(r'D:\Estudo\Oficina de Pesquisa\Dados Brutos\Vidigal\*'))

# %% [markdown]
# Concatenando as tabelas

# %%
abv_total = pd.concat((pd.read_fwf(count)for count in abv))
anchi_total = pd.concat((pd.read_fwf(count)for count in anchi))
am_total = pd.concat((pd.read_fwf(count)for count in am))
bangu_total = pd.concat((pd.read_fwf(count)for count in bangu))
bar_total = pd.concat((pd.read_fwf(count)for count in bar))
cg_total = pd.concat((pd.read_fwf(count)for count in cg))
cdd_total = pd.concat((pd.read_fwf(count)for count in cdd))
copa_total = pd.concat((pd.read_fwf(count)for count in copa))
grajau_total = pd.concat((pd.read_fwf(count)for count in grajau))
grajaca_total = pd.concat((pd.read_fwf(count)for count in grajaca))
grota_total = pd.concat((pd.read_fwf(count)for count in grota))
guaratiba_total = pd.concat((pd.read_fwf(count)for count in guaratiba))
ilha_total = pd.concat((pd.read_fwf(count)for count in ilha))
iraja_total = pd.concat((pd.read_fwf(count)for count in iraja))
jardimbo_total = pd.concat((pd.read_fwf(count)for count in jardimbo))
laranjeiras_total = pd.concat((pd.read_fwf(count)for count in laranjeiras))
madu_total = pd.concat((pd.read_fwf(count)for count in madu))
meier_total = pd.concat((pd.read_fwf(count)for count in meier))
penha_total = pd.concat((pd.read_fwf(count)for count in penha))
piedade_total = pd.concat((pd.read_fwf(count)for count in piedade))
recreio_total = pd.concat((pd.read_fwf(count)for count in recreio))
riocentro_total = pd.concat((pd.read_fwf(count)for count in riocentro))
rocinha_total = pd.concat((pd.read_fwf(count)for count in rocinha))
santacruz_total = pd.concat((pd.read_fwf(count)for count in santacruz))
santateresa_total = pd.concat((pd.read_fwf(count)for count in santateresa))
saocristo_total = pd.concat((pd.read_fwf(count)for count in saocristo))
saude_total = pd.concat((pd.read_fwf(count)for count in saude))
sepetiba_total = pd.concat((pd.read_fwf(count)for count in sepetiba))
tanque_total = pd.concat((pd.read_fwf(count)for count in tanque))
tijuca_total = pd.concat((pd.read_fwf(count)for count in tijuca))
tijucamuda_total = pd.concat((pd.read_fwf(count)for count in tijucamuda))
urca_total = pd.concat((pd.read_fwf(count)for count in urca))
vidigal_total = pd.concat((pd.read_fwf(count)for count in vidigal))

# %% [markdown]
# Primeira Correção - Tirada de linhas específicas:
#
# 1º Grupo(10)

# %%
#Alto da Boa Vista:
df_remove = abv_total.loc[(abv_total['Relatório Pluviométrico da Estação: Alto da Boa Vista'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (abv_total['Relatório Pluviométrico da Estação: Alto da Boa Vista'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (abv_total['Relatório Pluviométrico da Estação: Alto da Boa Vista'] == "Relatório Pluviométrico da Estação: Alto da Boa Vista")]
abv_total = abv_total.drop(df_remove.index)

#Anchieta:
df_remove = anchi_total.loc[(anchi_total['Relatório Pluviométrico da Estação: Anchieta'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (anchi_total['Relatório Pluviométrico da Estação: Anchieta'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (anchi_total['Relatório Pluviométrico da Estação: Anchieta'] == "Relatório Pluviométrico da Estação: Av. Brasil/Mendanha")]
anchi_total = anchi_total.drop(df_remove.index)

#Av. Brasil/Mendanha:
df_remove = am_total.loc[(am_total['Relatório Pluviométrico da Estação: Av. Brasil/Mendanha'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (am_total['Relatório Pluviométrico da Estação: Av. Brasil/Mendanha'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (am_total['Relatório Pluviométrico da Estação: Av. Brasil/Mendanha'] == "Relatório Pluviométrico da Estação: Av. Brasil/Mendanha")]
am_total = am_total.drop(df_remove.index)

#Bangu:
df_remove = bangu_total.loc[(bangu_total['Relatório Pluviométrico da Estação: Bangu'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (bangu_total['Relatório Pluviométrico da Estação: Bangu'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (bangu_total['Relatório Pluviométrico da Estação: Bangu'] == "Relatório Pluviométrico da Estação: Bangu")]
bangu_total = bangu_total.drop(df_remove.index)

#Barra/Barrinha:
df_remove = bar_total.loc[(bar_total['Relatório Pluviométrico da Estação: Barra/Barrinha'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (bar_total['Relatório Pluviométrico da Estação: Barra/Barrinha'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (bar_total['Relatório Pluviométrico da Estação: Barra/Barrinha'] == "Relatório Pluviométrico da Estação: Barra/Barrinha")]
bar_total = bar_total.drop(df_remove.index)

#Campo Grande:
df_remove = cg_total.loc[(cg_total['Relatório Pluviométrico da Estação: Campo Grande'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (cg_total['Relatório Pluviométrico da Estação: Campo Grande'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (cg_total['Relatório Pluviométrico da Estação: Campo Grande'] == "Relatório Pluviométrico da Estação: Campo Grande")]
cg_total = cg_total.drop(df_remove.index)

#Jacarepagua/Cidade de Deus:
df_remove = cdd_total.loc[(cdd_total['Relatório Pluviométrico da Estação: Jacarepagua/Cidade de Deus'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (cdd_total['Relatório Pluviométrico da Estação: Jacarepagua/Cidade de Deus'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (cdd_total['Relatório Pluviométrico da Estação: Jacarepagua/Cidade de Deus'] == "Relatório Pluviométrico da Estação: Jacarepagua/Cidade de Deus")]
cdd_total = cdd_total.drop(df_remove.index)

#Copacabana:
df_remove = copa_total.loc[(copa_total['Relatório Pluviométrico da Estação: Copacabana'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (copa_total['Relatório Pluviométrico da Estação: Copacabana'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (copa_total['Relatório Pluviométrico da Estação: Copacabana'] == "Relatório Pluviométrico da Estação: Copacabana")]
copa_total = copa_total.drop(df_remove.index)

#Grajau:
df_remove = grajau_total.loc[(grajau_total['Relatório Pluviométrico da Estação: Grajau'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (grajau_total['Relatório Pluviométrico da Estação: Grajau'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (grajau_total['Relatório Pluviométrico da Estação: Grajau'] == "Relatório Pluviométrico da Estação: Grajau")]
grajau_total = grajau_total.drop(df_remove.index)

#Est. Grajau/Jacarepagua:
df_remove = grajaca_total.loc[(grajaca_total['Relatório Pluviométrico da Estação: Est. Grajau/Jacarepagua'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (grajaca_total['Relatório Pluviométrico da Estação: Est. Grajau/Jacarepagua'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (grajaca_total['Relatório Pluviométrico da Estação: Est. Grajau/Jacarepagua'] == "Relatório Pluviométrico da Estação: Est. Grajau/Jacarepagua")]
grajaca_total = grajaca_total.drop(df_remove.index)

# %% [markdown]
# 2º Grupo:

# %%
#Grota Funda:
df_remove = grota_total.loc[(grota_total['Relatório Pluviométrico da Estação: Grota Funda'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (grota_total['Relatório Pluviométrico da Estação: Grota Funda'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (grota_total['Relatório Pluviométrico da Estação: Grota Funda'] == "Relatório Pluviométrico da Estação: Grota Funda")]
grota_total = grota_total.drop(df_remove.index)

#Guaratiba:
df_remove = guaratiba_total.loc[(guaratiba_total['Relatório Pluviométrico da Estação: Guaratiba'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (guaratiba_total['Relatório Pluviométrico da Estação: Guaratiba'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (guaratiba_total['Relatório Pluviométrico da Estação: Guaratiba'] == "Relatório Pluviométrico da Estação: Guaratiba")]
guaratiba_total = guaratiba_total.drop(df_remove.index)

#Ilha do Governador:
df_remove = ilha_total.loc[(ilha_total['Relatório Pluviométrico da Estação: Ilha do Governador'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (ilha_total['Relatório Pluviométrico da Estação: Ilha do Governador'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (ilha_total['Relatório Pluviométrico da Estação: Ilha do Governador'] == "Relatório Pluviométrico da Estação: Ilha do Governador")]
ilha_total = ilha_total.drop(df_remove.index)

#Iraja:
df_remove = iraja_total.loc[(iraja_total['Relatório Pluviométrico da Estação: Iraja'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (iraja_total['Relatório Pluviométrico da Estação: Iraja'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (iraja_total['Relatório Pluviométrico da Estação: Iraja'] == "Relatório Pluviométrico da Estação: Iraja")]
iraja_total = iraja_total.drop(df_remove.index)

#Jardim Botanico:
df_remove = jardimbo_total.loc[(jardimbo_total['Relatório Pluviométrico da Estação: Jardim Botanico'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (jardimbo_total['Relatório Pluviométrico da Estação: Jardim Botanico'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (jardimbo_total['Relatório Pluviométrico da Estação: Jardim Botanico'] == "Relatório Pluviométrico da Estação: Jardim Botanico")]
jardimbo_total = jardimbo_total.drop(df_remove.index)

#Laranjeiras:
df_remove = laranjeiras_total.loc[(laranjeiras_total['Relatório Pluviométrico da Estação: Laranjeiras'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (laranjeiras_total['Relatório Pluviométrico da Estação: Laranjeiras'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (laranjeiras_total['Relatório Pluviométrico da Estação: Laranjeiras'] == "Relatório Pluviométrico da Estação: Laranjeiras")]
laranjeiras_total = laranjeiras_total.drop(df_remove.index)

#Madureira:
df_remove = madu_total.loc[(madu_total['Relatório Pluviométrico da Estação: Madureira'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (madu_total['Relatório Pluviométrico da Estação: Madureira'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (madu_total['Relatório Pluviométrico da Estação: Madureira'] == "Relatório Pluviométrico da Estação: Madureira")]
madu_total = madu_total.drop(df_remove.index)

#Grande Meier:
df_remove = meier_total.loc[(meier_total['Relatório Pluviométrico da Estação: Grande Meier'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (meier_total['Relatório Pluviométrico da Estação: Grande Meier'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (meier_total['Relatório Pluviométrico da Estação: Grande Meier'] == "Relatório Pluviométrico da Estação: Grande Meier")]
meier_total = meier_total.drop(df_remove.index)

#Penha:
df_remove = penha_total.loc[(penha_total['Relatório Pluviométrico da Estação: Penha'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (penha_total['Relatório Pluviométrico da Estação: Penha'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (penha_total['Relatório Pluviométrico da Estação: Penha'] == "Relatório Pluviométrico da Estação: Penha")]
penha_total = penha_total.drop(df_remove.index)

#Piedade:
df_remove = piedade_total.loc[(piedade_total['Relatório Pluviométrico da Estação: Piedade'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (piedade_total['Relatório Pluviométrico da Estação: Piedade'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (piedade_total['Relatório Pluviométrico da Estação: Piedade'] == "Relatório Pluviométrico da Estação: Piedade")]
piedade_total = piedade_total.drop(df_remove.index)

# %% [markdown]
# 3º Grupo:

# %%
#Recreio dos Bandeirantes:
df_remove = recreio_total.loc[(recreio_total['Relatório Pluviométrico da Estação: Recreio dos Bandeirantes'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (recreio_total['Relatório Pluviométrico da Estação: Recreio dos Bandeirantes'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (recreio_total['Relatório Pluviométrico da Estação: Recreio dos Bandeirantes'] == "Relatório Pluviométrico da Estação: Recreio dos Bandeirantes")]
recreio_total = recreio_total.drop(df_remove.index)

#Barra/Rio Centro:
df_remove = riocentro_total.loc[(riocentro_total['Relatório Pluviométrico da Estação: Barra/Rio Centro'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (riocentro_total['Relatório Pluviométrico da Estação: Barra/Rio Centro'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (riocentro_total['Relatório Pluviométrico da Estação: Barra/Rio Centro'] == "Relatório Pluviométrico da Estação: Barra/Rio Centro")]
abv_total = riocentro_total.drop(df_remove.index)

#Rocinha:
df_remove = rocinha_total.loc[(rocinha_total['Relatório Pluviométrico da Estação: Rocinha'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (rocinha_total['Relatório Pluviométrico da Estação: Rocinha'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (rocinha_total['Relatório Pluviométrico da Estação: Rocinha'] == "Relatório Pluviométrico da Estação: Rocinha")]
rocinha_total = rocinha_total.drop(df_remove.index)

#Santa Cruz:
df_remove = santacruz_total.loc[(santacruz_total['Relatório Pluviométrico da Estação: Santa Cruz'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (santacruz_total['Relatório Pluviométrico da Estação: Santa Cruz'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (santacruz_total['Relatório Pluviométrico da Estação: Santa Cruz'] == "Relatório Pluviométrico da Estação: Santa Cruz")]
santacruz_total = santacruz_total.drop(df_remove.index)

#Santa Teresa:
df_remove = santateresa_total.loc[(santateresa_total['Relatório Pluviométrico da Estação: Santa Teresa'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (santateresa_total['Relatório Pluviométrico da Estação: Santa Teresa'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (santateresa_total['Relatório Pluviométrico da Estação: Santa Teresa'] == "Relatório Pluviométrico da Estação: Santa Teresa")]
santateresa_total = santateresa_total.drop(df_remove.index)

#Sao Cristovao:
df_remove = saocristo_total.loc[(saocristo_total['Relatório Pluviométrico da Estação: Sao Cristovao'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (saocristo_total['Relatório Pluviométrico da Estação: Sao Cristovao'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (saocristo_total['Relatório Pluviométrico da Estação: Sao Cristovao'] == "Relatório Pluviométrico da Estação: Sao Cristovao")]
saocristo_total = saocristo_total.drop(df_remove.index)

#Saude:
df_remove = saude_total.loc[(saude_total['Relatório Pluviométrico da Estação: Saude'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (saude_total['Relatório Pluviométrico da Estação: Saude'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (saude_total['Relatório Pluviométrico da Estação: Saude'] == "Relatório Pluviométrico da Estação: Saude")]
saude_total = saude_total.drop(df_remove.index)

#Sepetiba:
df_remove = sepetiba_total.loc[(sepetiba_total['Relatório Pluviométrico da Estação: Sepetiba'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (sepetiba_total['Relatório Pluviométrico da Estação: Sepetiba'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (sepetiba_total['Relatório Pluviométrico da Estação: Sepetiba'] == "Relatório Pluviométrico da Estação: Sepetiba")]
sepetiba_total = sepetiba_total.drop(df_remove.index)

#Jacarepagua/Tanque:
df_remove = tanque_total.loc[(tanque_total['Relatório Pluviométrico da Estação: Jacarepagua/Tanque'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (tanque_total['Relatório Pluviométrico da Estação: Jacarepagua/Tanque'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (tanque_total['Relatório Pluviométrico da Estação: Jacarepagua/Tanque'] == "Relatório Pluviométrico da Estação: Jacarepagua/Tanque")]
tanque_total = tanque_total.drop(df_remove.index)

#Tijuca:
df_remove = tijuca_total.loc[(tijuca_total['Relatório Pluviométrico da Estação: Tijuca'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (tijuca_total['Relatório Pluviométrico da Estação: Tijuca'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (tijuca_total['Relatório Pluviométrico da Estação: Tijuca'] == "Relatório Pluviométrico da Estação: Tijuca")]
tijuca_total = tijuca_total.drop(df_remove.index)

# %% [markdown]
# 4º Grupo:

# %%
#Tijuca/Muda:
df_remove = tijucamuda_total.loc[(tijucamuda_total['Relatório Pluviométrico da Estação: Tijuca/Muda'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (tijucamuda_total['Relatório Pluviométrico da Estação: Tijuca/Muda'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (tijucamuda_total['Relatório Pluviométrico da Estação: Tijuca/Muda'] == "Relatório Pluviométrico da Estação: Tijuca/Muda")]
tijucamuda_total = tijucamuda_total.drop(df_remove.index)

#Urca:
df_remove = urca_total.loc[(urca_total['Relatório Pluviométrico da Estação: Urca'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (urca_total['Relatório Pluviométrico da Estação: Urca'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (urca_total['Relatório Pluviométrico da Estação: Urca'] == "Relatório Pluviométrico da Estação: Urca")]
abv_total = urca_total.drop(df_remove.index)

#Alto da Boa Vista:
df_remove = vidigal_total.loc[(vidigal_total['Relatório Pluviométrico da Estação: Vidigal'] == "Dados normalizados para o Horário Brasileiro de Verão (HBV)") |
                      (vidigal_total['Relatório Pluviométrico da Estação: Vidigal'] == "Dia         Hora      HBV   15 min   01 h   04 h   24 h   96 h")|
                      (vidigal_total['Relatório Pluviométrico da Estação: Vidigal'] == "Relatório Pluviométrico da Estação: Vidigal")]
vidigal_total = vidigal_total.drop(df_remove.index)

# %% [markdown]
# Exportando como csv:

# %%
abv_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\abv_total.csv', index = False, sep = "\t")
anchi_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\anchi_total.csv', index = False, sep = "\t")
am_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\am_total.csv', index = False, sep = "\t")
bangu_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\bangu_total.csv', index = False, sep = "\t")
bar_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\bar_total.csv', index = False, sep = "\t")
cg_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\cg_total.csv', index = False, sep = "\t")
cdd_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\cdd_total.csv', index = False, sep = "\t")
copa_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\copa_total.csv', index = False, sep = "\t")
grajau_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\grajau_total.csv', index = False, sep = "\t")
grajaca_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\grajaca_total.csv', index = False, sep = "\t")
grota_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\grota_total.csv', index = False, sep = "\t")
guaratiba_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\guaratiba_total.csv', index = False, sep = "\t")
ilha_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\ilha_total.csv', index = False, sep = "\t")
iraja_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\iraja_total.csv', index = False, sep = "\t")
jardimbo_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\jardimbo_total.csv', index = False, sep = "\t")
laranjeiras_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\laranjeiras_total.csv', index = False, sep = "\t")
meier_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\meier_total.csv', index = False, sep = "\t")
madu_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\madu_total.csv', index = False, sep = "\t")
penha_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\penha_total.csv', index = False, sep = "\t")
piedade_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\piedade_total.csv', index = False, sep = "\t")
recreio_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\recreio_total.csv', index = False, sep = "\t")
riocentro_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\riocentro_total.csv', index = False, sep = "\t")
rocinha_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\rocinha_total.csv', index = False, sep = "\t")
saocristo_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\saocristo_total.csv', index = False, sep = "\t")
santacruz_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\santacruz_total.csv', index = False, sep = "\t")
santateresa_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\santateresa_total.csv', index = False, sep = "\t")
saude_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\saude_total.csv', index = False, sep = "\t")
sepetiba_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\sepetiba_total.csv', index = False, sep = "\t")
tanque_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\tanque_total.csv', index = False, sep = "\t")
tijuca_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\tijuca_total.csv', index = False, sep = "\t")
tijucamuda_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\tijucamuda_total.csv', index = False, sep = "\t")
urca_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\urca_total.csv', index = False, sep = "\t")
vidigal_total.to_csv(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\vidigal_total.csv', index = False, sep = "\t")

# %% [markdown]
# Copiando arquivos CSV para txt
#
# Aqui é uma questão pessoal... Com o nivel de conhecimento que eu tenho, do jeito que estou fazendo, estou mais
# adaptado ao txt.

# %%
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\abv_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\abv_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\anchi_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\anchi_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\am_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\am_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\bangu_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\bangu_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\bar_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\bar_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\cg_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\cg_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\cdd_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\cdd_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\copa_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\copa_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\grajau_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\grajau_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\grajaca_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\grajaca_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\grota_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\grota_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\guaratiba_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\guaratiba_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\ilha_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\ilha_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\iraja_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\iraja_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\jardimbo_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\jardimbo_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\laranjeiras_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\laranjeiras_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\meier_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\meier_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\madu_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\madu_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\penha_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\penha_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\piedade_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\piedade_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\recreio_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\recreio_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\riocentro_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\riocentro_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\rocinha_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\rocinha_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\saocristo_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\saocristo_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\santacruz_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\santacruz_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\santateresa_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\santateresa_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\saude_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\saude_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\sepetiba_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\sepetiba_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\tanque_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\tanque_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\tijuca_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\tijuca_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\tijucamuda_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\tijucamuda_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\urca_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\urca_total.txt')
shutil.copy(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\vidigal_total.csv',r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\vidigal_total.txt')
# Out:
# 'D:\\Estudo\\Oficina de Pesquisa\\Dados Tratados\\vidigal_total.txt'

# %% [markdown]
# Apagando Arquivos CSV:

# %%
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\abv_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\anchi_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\am_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\bangu_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\bar_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\cg_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\cdd_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\copa_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\grajau_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\grajaca_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\grota_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\guaratiba_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\ilha_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\iraja_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\jardimbo_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\laranjeiras_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\meier_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\madu_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\penha_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\piedade_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\recreio_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\riocentro_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\rocinha_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\saocristo_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\santacruz_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\santateresa_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\saude_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\sepetiba_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\tanque_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\tijuca_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\tijucamuda_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\urca_total.csv')
remove(r'D:\Estudo\Oficina de Pesquisa\Dados Tratados\vidigal_total.csv')
